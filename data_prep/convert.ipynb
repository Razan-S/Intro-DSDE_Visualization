# %%
import os
import json
import pandas as pd
import os
import numpy as np

from dotenv import load_dotenv

# %%
load_dotenv()

path_to_project_folder = os.getenv('project_folder')
current_folder = os.getenv('current_folder')
literatures_list_path = os.path.join(current_folder, 'data/literatures_list.txt')

# %%
subject_areas_df = pd.read_csv(r'./data/subject_areas.csv')

subject_areas_dict = dict(zip(subject_areas_df['Scopus Code'].astype(str), subject_areas_df['Subject Areas']))

# %%
# Create all path in the folder
# 
# with open(literatures_list_path, 'w') as file:
#     for path in os.listdir(path_to_project_folder):
#         folder_path = os.path.join(path_to_project_folder, path)
#         if os.path.isdir(folder_path):
#             for lit in os.listdir(folder_path):
#                 file_path = os.path.join(folder_path, lit)
#                 if os.path.isfile(file_path):
#                     file.write(file_path + '\n')

# %%
class Scopus:
    def __init__(self, article, code):
        self.article = article
        self.code = code

        self.title = None
        self.abstract = None
        self.publication_date = None
        self.prism_type = None
        self.keywords = None
        self.prism_type = None
        self.ref_count = None
        self.subject_areas = None
        self.publisher = None
        self.authors = None
        self.affiliation = None

    def title_convert(self):
        self.title = self.article['abstracts-retrieval-response']['coredata'].get("dc:title", None)

    def abstract_convert(self):
        self.abstract = self.article['abstracts-retrieval-response']['coredata'].get("dc:description", None)

    def publication_date_convert(self):
        publication = self.article['abstracts-retrieval-response']['item']['bibrecord']['head']['source']['publicationdate']
        
        year = publication.get("year", "Unknown")
        month = publication.get("month", "01")
        day = publication.get("day", "01")
        
        if year == "Unknown":
            self.publication_date = "Unknown"
        else:
            month = f"{int(month):02}" if month.isdigit() else "01"
            day = f"{int(day):02}" if day.isdigit() else "01"
            
            # ISO 8601 format
            self.publication_date = f"{year}-{month}-{day}"

    def prism_type_convert(self):
        self.prism_type = self.article['abstracts-retrieval-response']['coredata'].get("prism:aggregationType", None)
                                                                       
    def keywords_convert(self):
        if self.article['abstracts-retrieval-response'].get('authkeywords') is not None:
            keywords = self.article['abstracts-retrieval-response']['authkeywords'].get("author-keyword", None)
            if isinstance(keywords, list):
                k = ';'.join(keyword['$'].replace(' ', '') for keyword in keywords)
                self.keywords = k
            else:
                self.keywords = None
        else:
            self.keywords = None
    
    def subject_areas_convert(self):
        areas = self.article['abstracts-retrieval-response']['subject-areas'].get('subject-area', None) #array

        # for area in areas:
        #     code = round(int(area['@code'])/100)
        #     code = str(code*100)    
        #     name = subject_areas_dict[code]
        if areas is not None:
            a = ';'.join(subject_areas_dict[str(round(int(area['@code'])/100)*100)] for area in areas)
            self.subject_areas = a

    def ref_count_convert(self):
        tail = self.article['abstracts-retrieval-response']['item']['bibrecord']['tail']

        if tail is not None:
            count = tail.get("bibliography").get("@refcount", None)
            if count is not None:
                self.ref_count = int(count)
    
    def publisher_convert(self):
        self.publisher = self.article['abstracts-retrieval-response']['coredata'].get("dc:publisher", None)
                                                            
    def affiliation_convert(self):
        affiliations = self.article['abstracts-retrieval-response']['affiliation']
        if isinstance(affiliations, list):
            af = ';'.join(
                f"{aff['affilname']}, {aff['affiliation-country']}"
                for aff in affiliations
            )

            self.affiliation = af
            
        else:
            self.affiliation = f"{affiliations['affilname']}, {affiliations['affiliation-country']}"
        
    def authors_convert(self):
        authors = self.article['abstracts-retrieval-response']['authors']['author']
        
        if isinstance(authors, list):
            # for author in authors:
            #     f_name = author['preferred-name']['ce:given-name']
            #     s_name = author['preferred-name']['ce:surname']

            #     s += "{} {}, ".format(s_name, f_name)

            s = ';'.join(
                f"{author['preferred-name']['ce:surname']} {author['preferred-name']['ce:given-name']}"
                for author in authors
                )

            self.authors = s
        else:
            self.authors = None

    def extract(self):
        self.title_convert()
        self.abstract_convert()
        self.publication_date_convert()
        self.prism_type_convert()
        self.keywords_convert()
        self.subject_areas_convert()
        self.ref_count_convert()
        self.publisher_convert()
        self.affiliation_convert()
        self.authors_convert()

        return {
            "code": self.code,
            "title": self.title,
            "abstract": self.abstract,
            "publication_date": self.publication_date,
            "prism_type": self.prism_type,
            "keywords": self.keywords,
            "subject_area": self.subject_areas,
            "ref_count": self.ref_count,
            "publisher": self.publisher,
            "affiliation": self.affiliation,
            "authors": self.authors
        }

    def append_article(self, df):
        article_data = self.extract()
        
        new_row = pd.DataFrame([article_data])
        df = pd.concat([df, new_row], ignore_index=True)
        return df

# %%
df = pd.DataFrame(columns=[
    "code", "title", "abstract", "publication_date", 
    "prism_type", "keywords", "subject_area", 
    "ref_count", "publisher", "affiliation", "authors"
])

# %%
with open(literatures_list_path, 'r') as file:
    for line in file:
        literature_path = line.strip()
        try:
            with open(literature_path, 'r', encoding='utf-8') as lit:
                code = lit.name[-9:]

                article = json.load(lit)
                scopus = Scopus(article=article, code=code)
                df = scopus.append_article(df)
                break

        except FileNotFoundError:
            print(f'File not found: {literature_path}')
        except Exception as e:
            print(f'Error processing file {literature_path}: {e}')

# %%
with open(literatures_list_path, 'r') as file:
    for line in file:
        literature_path = line.strip()
        try:
            with open(literature_path, 'r', encoding='utf-8') as lit:
                code = lit.name[-9:]

                article = json.load(lit)
                scopus = Scopus(article=article, code=code)
                df = scopus.append_article(df)

        except FileNotFoundError:
            print(f'File not found: {literature_path}')
        except Exception as e:
            print(f'Error processing file {literature_path}: {e}')

# %%
df
# Out:
#             code                                              title  \
# 0      201800000  Public health and international epidemiology f...
# 1      201800000  Public health and international epidemiology f...
# 2      201800001  Flexible Printed Active Antenna for Digital Te...
# 3      201800002  Parametric study of hydrogen production via so...
# 4      201800003  Superhydrophobic coating from fluoroalkylsilan...
# ...          ...                                                ...
# 20212  202302885  Long-chain bio-olefins production via oxidativ...
# 20213  202302886  Recent Developments and Applications of Microf...
# 20214  202302887  Social justice, education and peacebuilding: c...
# 20215  202302888  Effects of black soldier fly (Hermetia illucen...
# 20216  202302889  Effects of remittances on household poverty an...
#
#                                                 abstract publication_date  \
# 0                                                   None       2018-12-31
# 1                                                   None       2018-12-31
# 2      This paper presents the development of a flexi...       2018-12-31
# 3      Computational fluid dynamics was applied for s...       2018-12-31
# 4      A superhydrophobic/superoleophilic mesh was su...       2018-12-31
# ...                                                  ...              ...
# 20212  Long-chain α-olefins (≥ C10) are normally appl...       2023-01-01
# 20213  Nowadays, food safety has become a major conce...       2023-01-01
# 20214  Education is increasingly becoming central to ...       2023-01-01
# 20215  The effects of replacing fish meal protein wit...       2023-01-01
# 20216  The author uses data from the Cambodia Socio-E...       2023-01-01
#
#                   prism_type  \
# 0                       Book
# 1                       Book
# 2      Conference Proceeding
# 3                    Journal
# 4                    Journal
# ...                      ...
# 20212                Journal
# 20213                Journal
# 20214                Journal
# 20215                Journal
# 20216                Journal
#
#                                                 keywords  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      Circulatingfluidizedbed;Computationalfluiddyna...
# 4      Encapsulation;Fluoroalkylsilane;Naturalrubber;...
# ...                                                  ...
# 20212  Long-chainolefins;MesoporousKIT-6;Oleicacid;Ox...
# 20213  Biologicalhazards;chemicalhazards;foodcontamin...
# 20214  conflict;Education;peacebuilding;socialjustice...
# 20215  Anabastestudineus;Blacksoldierfly;fishmealrepl...
# 20216  Cambodia;consumption;expenditure;Impact;inequa...
#
#                                             subject_area ref_count  \
# 0                                               Medicine        76
# 1                                               Medicine        76
# 2                          Engineering;Materials Science         4
# 3             Chemistry;Chemical Engineering;Engineering        42
# 4      Chemistry;Physics and Astronomy;Physics and As...        45
# ...                                                  ...       ...
# 20212                     Chemical Engineering;Chemistry        63
# 20213                                          Chemistry       115
# 20214                                    Social Sciences        76
# 20215  Environmental Science;Agricultural and Biologi...        44
# 20216    Social Sciences;Social Sciences;Social Sciences        58
#
#                                                publisher  \
# 0                      Springer International Publishing
# 1                      Springer International Publishing
# 2      Institute of Electrical and Electronics Engine...
# 3                                           Elsevier Ltd
# 4                                          Elsevier B.V.
# ...                                                  ...
# 20212                                      Elsevier B.V.
# 20213                            Taylor and Francis Ltd.
# 20214                                          Routledge
# 20215                            Taylor and Francis Ltd.
# 20216                                          Routledge
#
#                                              affiliation  \
# 0      Stanford University School of Medicine, United...
# 1      Stanford University School of Medicine, United...
# 2                     Chulalongkorn University, Thailand
# 3                     Chulalongkorn University, Thailand
# 4      Hirosaki University, Japan;Chulalongkorn Unive...
# ...                                                  ...
# 20212  Chulalongkorn University, Thailand;Center of E...
# 20213                 Chulalongkorn University, Thailand
# 20214  Chulalongkorn University, Thailand;UCL Institu...
# 20215  Chulalongkorn University, Thailand;Khon Kaen U...
# 20216  Chulalongkorn University, Thailand;Cambodia Un...
#
#                                                  authors
# 0                      Pongpirul Krit;Lungren Matthew P.
# 1                      Pongpirul Krit;Lungren Matthew P.
# 2                 Pratumsiri Teerapong;Janpugdee Panuwat
# 3      Phuakpunk Kiattikhoon;Chalermsinsuwan Benjapon...
# 4      Saengkaew Jittraporn;Le Duy;Samart Chanatip;Sa...
# ...                                                  ...
# 20212  Le Duy;Chaidherasuwet Nattaporn;Rueangthaweep ...
# 20213  Alahmad Waleed;Varanusupakul Puttaruksa;Varanu...
# 20214                                   Pherali Tejendra
# 20215  Mapanao Ratchaneegorn;Jiwyam Wirat;Nithikulwor...
# 20216                                        Chea Vatana
#
# [20217 rows x 11 columns]

# %% [markdown]
# Approximately Under 10 minutes

# %%
path_articles = r'data/scopus_data.csv'

df.to_csv(path_articles, index=False)
